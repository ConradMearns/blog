# %%
# !ls ~/xochitl
# Out:
# 03766208-d270-41f8-8f78-0b0a28f37be9
# 03766208-d270-41f8-8f78-0b0a28f37be9.content
# 03766208-d270-41f8-8f78-0b0a28f37be9.metadata
# 03766208-d270-41f8-8f78-0b0a28f37be9.pagedata
# 03766208-d270-41f8-8f78-0b0a28f37be9.thumbnails
# 0427dae3-baae-46d4-91d9-59a18c495e52
# 0427dae3-baae-46d4-91d9-59a18c495e52.content
# 0427dae3-baae-46d4-91d9-59a18c495e52.metadata
# 0427dae3-baae-46d4-91d9-59a18c495e52.pagedata
# 0427dae3-baae-46d4-91d9-59a18c495e52.pdf
# 0427dae3-baae-46d4-91d9-59a18c495e52.thumbnails
# 0531b3e3-2aab-4b31-8fab-7c81e2f26d0d
# 0531b3e3-2aab-4b31-8fab-7c81e2f26d0d.content
# 0531b3e3-2aab-4b31-8fab-7c81e2f26d0d.metadata
# 0531b3e3-2aab-4b31-8fab-7c81e2f26d0d.pagedata
# 0531b3e3-2aab-4b31-8fab-7c81e2f26d0d.pdf
# 0531b3e3-2aab-4b31-8fab-7c81e2f26d0d.thumbnails
# 0531b3e3-2aab-4b31-8fab-7c81e2f26d0d_1.zip.part
# 0596199b-3c0e-4f35-b288-e37ba4f76a04
# 0596199b-3c0e-4f35-b288-e37ba4f76a04.content
# 0596199b-3c0e-4f35-b288-e37ba4f76a04.highlights
# ...

# %%
import os
for file in os.listdir ('/home/conrad/xochitl'):
    if file.endswith("content"):
        print(file)
# Out:
# 5aeaa165-c7af-467a-88b7-3b6706135a0a.content
# 3fdcdd24-8070-4ee6-b7e2-b5452bb1b651.content
# 2c338443-6af0-4fa9-9aa3-4b9a3655b91c.content
# 0bc21629-2dcb-464e-9cec-6f5e8f0b91cb.content
# fb0864de-7a0f-4490-9310-2979443e2755.content
# eee535ed-4063-4500-bc21-281b91eb54df.content
# 864091c5-49fc-4183-930f-e32300eb638f.content
# 2e14bfe3-1449-447d-ab15-38fb49de92b1.content
# deed22f9-5baf-4326-8789-5b0fc5f1e4ff.content
# 14b1e7d7-079a-4b81-a907-e92d83481c72.content
# 0427dae3-baae-46d4-91d9-59a18c495e52.content
# 12c6a0dd-efe5-459f-9492-94235393187a.content
# 399d48ce-1f5a-42c8-b45a-ff8997bca0e7.content
# 7452fe86-e855-4bb5-a309-454dd37524b0.content
# a09edfe7-4682-4cec-80b8-eb2e606c43c2.content
# 4fe1b9f2-ca38-415d-bdf1-e0aa5838d9b2.content
# 6132ccf1-fef7-447d-b5dc-f4647647aec4.content
# 2cd46823-d694-4967-a74b-6fe78d03d459.content
# 5f3f2218-e0c8-4d0e-a298-62664a43de1f.content
# beed86a4-0cdc-4347-a218-3f64f800094b.content
# f89deeb4-1af5-44b6-9ea0-3fef6d36e417.content
# ...

# %%
# !ls ~/xochitl/03766208-d270-41f8-8f78-0b0a28f37be9/
# Out:
# 0e96053f-31bb-4746-a097-5453c6f6a7a7-metadata.json
# 0e96053f-31bb-4746-a097-5453c6f6a7a7.rm
# 15ab39a8-cbb5-4c66-bf5a-88df18b9755c-metadata.json
# 15ab39a8-cbb5-4c66-bf5a-88df18b9755c.rm
# 16739ac6-03c9-47ca-91a0-86ac786dd7ac-metadata.json
# 16739ac6-03c9-47ca-91a0-86ac786dd7ac.rm
# 1fc3784a-e6f5-494b-b05c-51d0bf5d850d-metadata.json
# 1fc3784a-e6f5-494b-b05c-51d0bf5d850d.rm
# 37093fd3-d930-4e94-a3d3-eb4a2e6af1fc-metadata.json
# 37093fd3-d930-4e94-a3d3-eb4a2e6af1fc.rm
# 72f56dc9-c663-4ece-918c-8b454619c62a-metadata.json
# 72f56dc9-c663-4ece-918c-8b454619c62a.rm
# 7ad9886e-ce68-46e2-913c-66676f58dbd1-metadata.json
# 7ad9886e-ce68-46e2-913c-66676f58dbd1.rm
# bbe24cea-9c93-407f-a4a6-1d5f8a899735-metadata.json
# bbe24cea-9c93-407f-a4a6-1d5f8a899735.rm
# dbfe6aa7-84a8-4b95-af34-17467237e40c.rm
# f6d5e6bd-5741-478a-b09c-b9fe2ba23e77-metadata.json
# f6d5e6bd-5741-478a-b09c-b9fe2ba23e77.rm

# %%
from pathlib import Path
from rmlines import RMLines

p = Path("~/xochitl/03766208-d270-41f8-8f78-0b0a28f37be9/0e96053f-31bb-4746-a097-5453c6f6a7a7.rm")
rm0 = RMLines.from_bytes(p.open("rb"))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-59ad5670e795> in <module>
#       1 from pathlib import Path
# ----> 2 from rmlines import RMLines
#       3
#       4 p = Path("~/xochitl/03766208-d270-41f8-8f78-0b0a28f37be9/0e96053f-31bb-4746-a097-5453c6f6a7a7.rm")
#       5 rm0 = RMLines.from_bytes(p.open("rb"))
#
# ModuleNotFoundError: No module named 'rmlines'
